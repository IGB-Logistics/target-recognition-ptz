# %%
import torch
import cv2
import numpy as np
import sys
sys.path.append("../../deep_sort_lite")  # 添加上一级目录到模块搜索路径

# export mobileNetV2_bottle as onnx model
from embedder.embedder_pytorch import MobileNetv2_Embedder as Embedder

onnx_path = "../../model/mobilenetv2.onnx"  # 输出文件的路径
img = cv2.imread("./dog.jpg")

# load pytorch model
embedder = Embedder()
feats = embedder.predict([img])
print(feats)
# Out:
# [array([0.23643717, 1.2312804 , 1.8156879 , ..., 0.10831741, 0.16737019,
#        0.70336944], dtype=float32)]

# %%
# export onnx model
model  = embedder.model
model.eval()
print(model)
dummy_input = torch.randn(1,3,224,224)  # 假设输入是这个形状
torch.onnx.export(model, dummy_input, onnx_path, export_params=True, opset_version=11)
# Out:
# MobileNetV2_bottle(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (4): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#         (4): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (4): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#         (4): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#         (3): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#         (4): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU6(inplace=True)
#         (6): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (7): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Sequential(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
# )

# %%
# load onnx model
import onnx
import onnxruntime as ort

onnx_model = onnx.load(onnx_path)

# 打印输入和输出
print("Inputs: ", onnx_model.graph.input)
print("Outputs: ", onnx_model.graph.output)

onnx.checker.check_model(onnx_model)
# 打印模型的层
print(onnx.helper.printable_graph(onnx_model.graph))

# 创建一个运行时会话
sess = ort.InferenceSession(onnx_path)

# 输入是一个形状为 (1, 3, 224, 224) 的张量
img_tensor = embedder.preprocess(img)[0]
img_array = np.expand_dims(img_tensor, axis=0)
input_name = sess.get_inputs()[0].name

# 运行模型
result = sess.run(None, {input_name: img_array})

# 打印结果
print(result)
# Out:
# Inputs:  [name: "input.1"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 3
#       }
#       dim {
#         dim_value: 224
#       }
#       dim {
#         dim_value: 224
#       }
#     }
#   }
# }
# ]
# Outputs:  [name: "533"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 1280
#       }
#     }
#   }
# }
# ]
# graph torch_jit (
#   %input.1[FLOAT, 1x3x224x224]
# ) initializers (
#   %onnx::Conv_535[FLOAT, 32x3x3x3]
#   %onnx::Conv_536[FLOAT, 32]
#   %onnx::Conv_538[FLOAT, 32x1x3x3]
#   %onnx::Conv_539[FLOAT, 32]
#   %onnx::Conv_541[FLOAT, 16x32x1x1]
#   %onnx::Conv_542[FLOAT, 16]
#   %onnx::Conv_544[FLOAT, 96x16x1x1]
#   %onnx::Conv_545[FLOAT, 96]
#   %onnx::Conv_547[FLOAT, 96x1x3x3]
#   %onnx::Conv_548[FLOAT, 96]
#   %onnx::Conv_550[FLOAT, 24x96x1x1]
#   %onnx::Conv_551[FLOAT, 24]
#   %onnx::Conv_553[FLOAT, 144x24x1x1]
#   %onnx::Conv_554[FLOAT, 144]
#   %onnx::Conv_556[FLOAT, 144x1x3x3]
#   %onnx::Conv_557[FLOAT, 144]
#   %onnx::Conv_559[FLOAT, 24x144x1x1]
#   %onnx::Conv_560[FLOAT, 24]
#   %onnx::Conv_562[FLOAT, 144x24x1x1]
#   %onnx::Conv_563[FLOAT, 144]
#   %onnx::Conv_565[FLOAT, 144x1x3x3]
#   %onnx::Conv_566[FLOAT, 144]
#   %onnx::Conv_568[FLOAT, 32x144x1x1]
#   %onnx::Conv_569[FLOAT, 32]
#   %onnx::Conv_571[FLOAT, 192x32x1x1]
#   %onnx::Conv_572[FLOAT, 192]
#   %onnx::Conv_574[FLOAT, 192x1x3x3]
#   %onnx::Conv_575[FLOAT, 192]
#   %onnx::Conv_577[FLOAT, 32x192x1x1]
#   %onnx::Conv_578[FLOAT, 32]
#   %onnx::Conv_580[FLOAT, 192x32x1x1]
#   %onnx::Conv_581[FLOAT, 192]
#   %onnx::Conv_583[FLOAT, 192x1x3x3]
#   %onnx::Conv_584[FLOAT, 192]
#   %onnx::Conv_586[FLOAT, 32x192x1x1]
#   %onnx::Conv_587[FLOAT, 32]
#   %onnx::Conv_589[FLOAT, 192x32x1x1]
#   %onnx::Conv_590[FLOAT, 192]
#   %onnx::Conv_592[FLOAT, 192x1x3x3]
#   %onnx::Conv_593[FLOAT, 192]
#   %onnx::Conv_595[FLOAT, 64x192x1x1]
#   %onnx::Conv_596[FLOAT, 64]
#   %onnx::Conv_598[FLOAT, 384x64x1x1]
#   %onnx::Conv_599[FLOAT, 384]
#   %onnx::Conv_601[FLOAT, 384x1x3x3]
#   %onnx::Conv_602[FLOAT, 384]
#   %onnx::Conv_604[FLOAT, 64x384x1x1]
#   %onnx::Conv_605[FLOAT, 64]
#   %onnx::Conv_607[FLOAT, 384x64x1x1]
#   %onnx::Conv_608[FLOAT, 384]
#   %onnx::Conv_610[FLOAT, 384x1x3x3]
#   %onnx::Conv_611[FLOAT, 384]
#   %onnx::Conv_613[FLOAT, 64x384x1x1]
#   %onnx::Conv_614[FLOAT, 64]
#   %onnx::Conv_616[FLOAT, 384x64x1x1]
#   %onnx::Conv_617[FLOAT, 384]
#   %onnx::Conv_619[FLOAT, 384x1x3x3]
#   %onnx::Conv_620[FLOAT, 384]
#   %onnx::Conv_622[FLOAT, 64x384x1x1]
#   %onnx::Conv_623[FLOAT, 64]
#   %onnx::Conv_625[FLOAT, 384x64x1x1]
#   %onnx::Conv_626[FLOAT, 384]
#   %onnx::Conv_628[FLOAT, 384x1x3x3]
#   %onnx::Conv_629[FLOAT, 384]
#   %onnx::Conv_631[FLOAT, 96x384x1x1]
#   %onnx::Conv_632[FLOAT, 96]
#   %onnx::Conv_634[FLOAT, 576x96x1x1]
#   %onnx::Conv_635[FLOAT, 576]
#   %onnx::Conv_637[FLOAT, 576x1x3x3]
#   %onnx::Conv_638[FLOAT, 576]
#   %onnx::Conv_640[FLOAT, 96x576x1x1]
#   %onnx::Conv_641[FLOAT, 96]
#   %onnx::Conv_643[FLOAT, 576x96x1x1]
#   %onnx::Conv_644[FLOAT, 576]
#   %onnx::Conv_646[FLOAT, 576x1x3x3]
#   %onnx::Conv_647[FLOAT, 576]
#   %onnx::Conv_649[FLOAT, 96x576x1x1]
#   %onnx::Conv_650[FLOAT, 96]
#   %onnx::Conv_652[FLOAT, 576x96x1x1]
#   %onnx::Conv_653[FLOAT, 576]
#   %onnx::Conv_655[FLOAT, 576x1x3x3]
#   %onnx::Conv_656[FLOAT, 576]
#   %onnx::Conv_658[FLOAT, 160x576x1x1]
#   %onnx::Conv_659[FLOAT, 160]
#   %onnx::Conv_661[FLOAT, 960x160x1x1]
#   %onnx::Conv_662[FLOAT, 960]
#   %onnx::Conv_664[FLOAT, 960x1x3x3]
#   %onnx::Conv_665[FLOAT, 960]
#   %onnx::Conv_667[FLOAT, 160x960x1x1]
#   %onnx::Conv_668[FLOAT, 160]
#   %onnx::Conv_670[FLOAT, 960x160x1x1]
#   %onnx::Conv_671[FLOAT, 960]
#   %onnx::Conv_673[FLOAT, 960x1x3x3]
#   %onnx::Conv_674[FLOAT, 960]
#   %onnx::Conv_676[FLOAT, 160x960x1x1]
#   %onnx::Conv_677[FLOAT, 160]
#   %onnx::Conv_679[FLOAT, 960x160x1x1]
#   %onnx::Conv_680[FLOAT, 960]
#   %onnx::Conv_682[FLOAT, 960x1x3x3]
#   %onnx::Conv_683[FLOAT, 960]
#   %onnx::Conv_685[FLOAT, 320x960x1x1]
#   %onnx::Conv_686[FLOAT, 320]
#   %onnx::Conv_688[FLOAT, 1280x320x1x1]
#   %onnx::Conv_689[FLOAT, 1280]
# ) {
#   %/features/features.0/features.0.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%input.1, %onnx::Conv_535, %onnx::Conv_536)
#   %/features/features.0/features.0.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.0/features.0.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.0/features.0.2/Clip_output_0 = Clip(%/features/features.0/features.0.0/Conv_output_0, %/features/features.0/features.0.2/Constant_output_0, %/features/features.0/features.0.2/Constant_1_output_0)
#   %/features/features.1/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 32, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.0/features.0.2/Clip_output_0, %onnx::Conv_538, %onnx::Conv_539)
#   %/features/features.1/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.1/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.1/conv/conv.2/Clip_output_0 = Clip(%/features/features.1/conv/conv.0/Conv_output_0, %/features/features.1/conv/conv.2/Constant_output_0, %/features/features.1/conv/conv.2/Constant_1_output_0)
#   %/features/features.1/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/conv/conv.2/Clip_output_0, %onnx::Conv_541, %onnx::Conv_542)
#   %/features/features.2/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.1/conv/conv.3/Conv_output_0, %onnx::Conv_544, %onnx::Conv_545)
#   %/features/features.2/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.2/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.2/conv/conv.2/Clip_output_0 = Clip(%/features/features.2/conv/conv.0/Conv_output_0, %/features/features.2/conv/conv.2/Constant_output_0, %/features/features.2/conv/conv.2/Constant_1_output_0)
#   %/features/features.2/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 96, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.2/conv/conv.2/Clip_output_0, %onnx::Conv_547, %onnx::Conv_548)
#   %/features/features.2/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.2/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.2/conv/conv.5/Clip_output_0 = Clip(%/features/features.2/conv/conv.3/Conv_output_0, %/features/features.2/conv/conv.5/Constant_output_0, %/features/features.2/conv/conv.5/Constant_1_output_0)
#   %/features/features.2/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/conv/conv.5/Clip_output_0, %onnx::Conv_550, %onnx::Conv_551)
#   %/features/features.3/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.2/conv/conv.6/Conv_output_0, %onnx::Conv_553, %onnx::Conv_554)
#   %/features/features.3/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.3/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.3/conv/conv.2/Clip_output_0 = Clip(%/features/features.3/conv/conv.0/Conv_output_0, %/features/features.3/conv/conv.2/Constant_output_0, %/features/features.3/conv/conv.2/Constant_1_output_0)
#   %/features/features.3/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.3/conv/conv.2/Clip_output_0, %onnx::Conv_556, %onnx::Conv_557)
#   %/features/features.3/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.3/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.3/conv/conv.5/Clip_output_0 = Clip(%/features/features.3/conv/conv.3/Conv_output_0, %/features/features.3/conv/conv.5/Constant_output_0, %/features/features.3/conv/conv.5/Constant_1_output_0)
#   %/features/features.3/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/conv/conv.5/Clip_output_0, %onnx::Conv_559, %onnx::Conv_560)
#   %/features/features.3/Add_output_0 = Add(%/features/features.2/conv/conv.6/Conv_output_0, %/features/features.3/conv/conv.6/Conv_output_0)
#   %/features/features.4/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.3/Add_output_0, %onnx::Conv_562, %onnx::Conv_563)
#   %/features/features.4/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.4/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.4/conv/conv.2/Clip_output_0 = Clip(%/features/features.4/conv/conv.0/Conv_output_0, %/features/features.4/conv/conv.2/Constant_output_0, %/features/features.4/conv/conv.2/Constant_1_output_0)
#   %/features/features.4/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 144, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.4/conv/conv.2/Clip_output_0, %onnx::Conv_565, %onnx::Conv_566)
#   %/features/features.4/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.4/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.4/conv/conv.5/Clip_output_0 = Clip(%/features/features.4/conv/conv.3/Conv_output_0, %/features/features.4/conv/conv.5/Constant_output_0, %/features/features.4/conv/conv.5/Constant_1_output_0)
#   %/features/features.4/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/conv/conv.5/Clip_output_0, %onnx::Conv_568, %onnx::Conv_569)
#   %/features/features.5/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.4/conv/conv.6/Conv_output_0, %onnx::Conv_571, %onnx::Conv_572)
#   %/features/features.5/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.5/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.5/conv/conv.2/Clip_output_0 = Clip(%/features/features.5/conv/conv.0/Conv_output_0, %/features/features.5/conv/conv.2/Constant_output_0, %/features/features.5/conv/conv.2/Constant_1_output_0)
#   %/features/features.5/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 192, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.5/conv/conv.2/Clip_output_0, %onnx::Conv_574, %onnx::Conv_575)
#   %/features/features.5/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.5/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.5/conv/conv.5/Clip_output_0 = Clip(%/features/features.5/conv/conv.3/Conv_output_0, %/features/features.5/conv/conv.5/Constant_output_0, %/features/features.5/conv/conv.5/Constant_1_output_0)
#   %/features/features.5/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/conv/conv.5/Clip_output_0, %onnx::Conv_577, %onnx::Conv_578)
#   %/features/features.5/Add_output_0 = Add(%/features/features.4/conv/conv.6/Conv_output_0, %/features/features.5/conv/conv.6/Conv_output_0)
#   %/features/features.6/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.5/Add_output_0, %onnx::Conv_580, %onnx::Conv_581)
#   %/features/features.6/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.6/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.6/conv/conv.2/Clip_output_0 = Clip(%/features/features.6/conv/conv.0/Conv_output_0, %/features/features.6/conv/conv.2/Constant_output_0, %/features/features.6/conv/conv.2/Constant_1_output_0)
#   %/features/features.6/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 192, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.6/conv/conv.2/Clip_output_0, %onnx::Conv_583, %onnx::Conv_584)
#   %/features/features.6/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.6/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.6/conv/conv.5/Clip_output_0 = Clip(%/features/features.6/conv/conv.3/Conv_output_0, %/features/features.6/conv/conv.5/Constant_output_0, %/features/features.6/conv/conv.5/Constant_1_output_0)
#   %/features/features.6/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/conv/conv.5/Clip_output_0, %onnx::Conv_586, %onnx::Conv_587)
#   %/features/features.6/Add_output_0 = Add(%/features/features.5/Add_output_0, %/features/features.6/conv/conv.6/Conv_output_0)
#   %/features/features.7/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.6/Add_output_0, %onnx::Conv_589, %onnx::Conv_590)
#   %/features/features.7/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.7/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.7/conv/conv.2/Clip_output_0 = Clip(%/features/features.7/conv/conv.0/Conv_output_0, %/features/features.7/conv/conv.2/Constant_output_0, %/features/features.7/conv/conv.2/Constant_1_output_0)
#   %/features/features.7/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 192, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.7/conv/conv.2/Clip_output_0, %onnx::Conv_592, %onnx::Conv_593)
#   %/features/features.7/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.7/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.7/conv/conv.5/Clip_output_0 = Clip(%/features/features.7/conv/conv.3/Conv_output_0, %/features/features.7/conv/conv.5/Constant_output_0, %/features/features.7/conv/conv.5/Constant_1_output_0)
#   %/features/features.7/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/conv/conv.5/Clip_output_0, %onnx::Conv_595, %onnx::Conv_596)
#   %/features/features.8/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.7/conv/conv.6/Conv_output_0, %onnx::Conv_598, %onnx::Conv_599)
#   %/features/features.8/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.8/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.8/conv/conv.2/Clip_output_0 = Clip(%/features/features.8/conv/conv.0/Conv_output_0, %/features/features.8/conv/conv.2/Constant_output_0, %/features/features.8/conv/conv.2/Constant_1_output_0)
#   %/features/features.8/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 384, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.8/conv/conv.2/Clip_output_0, %onnx::Conv_601, %onnx::Conv_602)
#   %/features/features.8/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.8/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.8/conv/conv.5/Clip_output_0 = Clip(%/features/features.8/conv/conv.3/Conv_output_0, %/features/features.8/conv/conv.5/Constant_output_0, %/features/features.8/conv/conv.5/Constant_1_output_0)
#   %/features/features.8/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/conv/conv.5/Clip_output_0, %onnx::Conv_604, %onnx::Conv_605)
#   %/features/features.8/Add_output_0 = Add(%/features/features.7/conv/conv.6/Conv_output_0, %/features/features.8/conv/conv.6/Conv_output_0)
#   %/features/features.9/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.8/Add_output_0, %onnx::Conv_607, %onnx::Conv_608)
#   %/features/features.9/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.9/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.9/conv/conv.2/Clip_output_0 = Clip(%/features/features.9/conv/conv.0/Conv_output_0, %/features/features.9/conv/conv.2/Constant_output_0, %/features/features.9/conv/conv.2/Constant_1_output_0)
#   %/features/features.9/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 384, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.9/conv/conv.2/Clip_output_0, %onnx::Conv_610, %onnx::Conv_611)
#   %/features/features.9/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.9/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.9/conv/conv.5/Clip_output_0 = Clip(%/features/features.9/conv/conv.3/Conv_output_0, %/features/features.9/conv/conv.5/Constant_output_0, %/features/features.9/conv/conv.5/Constant_1_output_0)
#   %/features/features.9/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/conv/conv.5/Clip_output_0, %onnx::Conv_613, %onnx::Conv_614)
#   %/features/features.9/Add_output_0 = Add(%/features/features.8/Add_output_0, %/features/features.9/conv/conv.6/Conv_output_0)
#   %/features/features.10/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.9/Add_output_0, %onnx::Conv_616, %onnx::Conv_617)
#   %/features/features.10/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.10/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.10/conv/conv.2/Clip_output_0 = Clip(%/features/features.10/conv/conv.0/Conv_output_0, %/features/features.10/conv/conv.2/Constant_output_0, %/features/features.10/conv/conv.2/Constant_1_output_0)
#   %/features/features.10/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 384, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.10/conv/conv.2/Clip_output_0, %onnx::Conv_619, %onnx::Conv_620)
#   %/features/features.10/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.10/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.10/conv/conv.5/Clip_output_0 = Clip(%/features/features.10/conv/conv.3/Conv_output_0, %/features/features.10/conv/conv.5/Constant_output_0, %/features/features.10/conv/conv.5/Constant_1_output_0)
#   %/features/features.10/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/conv/conv.5/Clip_output_0, %onnx::Conv_622, %onnx::Conv_623)
#   %/features/features.10/Add_output_0 = Add(%/features/features.9/Add_output_0, %/features/features.10/conv/conv.6/Conv_output_0)
#   %/features/features.11/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.10/Add_output_0, %onnx::Conv_625, %onnx::Conv_626)
#   %/features/features.11/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.11/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.11/conv/conv.2/Clip_output_0 = Clip(%/features/features.11/conv/conv.0/Conv_output_0, %/features/features.11/conv/conv.2/Constant_output_0, %/features/features.11/conv/conv.2/Constant_1_output_0)
#   %/features/features.11/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 384, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.11/conv/conv.2/Clip_output_0, %onnx::Conv_628, %onnx::Conv_629)
#   %/features/features.11/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.11/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.11/conv/conv.5/Clip_output_0 = Clip(%/features/features.11/conv/conv.3/Conv_output_0, %/features/features.11/conv/conv.5/Constant_output_0, %/features/features.11/conv/conv.5/Constant_1_output_0)
#   %/features/features.11/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/conv/conv.5/Clip_output_0, %onnx::Conv_631, %onnx::Conv_632)
#   %/features/features.12/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.11/conv/conv.6/Conv_output_0, %onnx::Conv_634, %onnx::Conv_635)
#   %/features/features.12/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.12/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.12/conv/conv.2/Clip_output_0 = Clip(%/features/features.12/conv/conv.0/Conv_output_0, %/features/features.12/conv/conv.2/Constant_output_0, %/features/features.12/conv/conv.2/Constant_1_output_0)
#   %/features/features.12/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.12/conv/conv.2/Clip_output_0, %onnx::Conv_637, %onnx::Conv_638)
#   %/features/features.12/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.12/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.12/conv/conv.5/Clip_output_0 = Clip(%/features/features.12/conv/conv.3/Conv_output_0, %/features/features.12/conv/conv.5/Constant_output_0, %/features/features.12/conv/conv.5/Constant_1_output_0)
#   %/features/features.12/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/conv/conv.5/Clip_output_0, %onnx::Conv_640, %onnx::Conv_641)
#   %/features/features.12/Add_output_0 = Add(%/features/features.11/conv/conv.6/Conv_output_0, %/features/features.12/conv/conv.6/Conv_output_0)
#   %/features/features.13/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.12/Add_output_0, %onnx::Conv_643, %onnx::Conv_644)
#   %/features/features.13/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.13/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.13/conv/conv.2/Clip_output_0 = Clip(%/features/features.13/conv/conv.0/Conv_output_0, %/features/features.13/conv/conv.2/Constant_output_0, %/features/features.13/conv/conv.2/Constant_1_output_0)
#   %/features/features.13/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.13/conv/conv.2/Clip_output_0, %onnx::Conv_646, %onnx::Conv_647)
#   %/features/features.13/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.13/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.13/conv/conv.5/Clip_output_0 = Clip(%/features/features.13/conv/conv.3/Conv_output_0, %/features/features.13/conv/conv.5/Constant_output_0, %/features/features.13/conv/conv.5/Constant_1_output_0)
#   %/features/features.13/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/conv/conv.5/Clip_output_0, %onnx::Conv_649, %onnx::Conv_650)
#   %/features/features.13/Add_output_0 = Add(%/features/features.12/Add_output_0, %/features/features.13/conv/conv.6/Conv_output_0)
#   %/features/features.14/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.13/Add_output_0, %onnx::Conv_652, %onnx::Conv_653)
#   %/features/features.14/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.14/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.14/conv/conv.2/Clip_output_0 = Clip(%/features/features.14/conv/conv.0/Conv_output_0, %/features/features.14/conv/conv.2/Constant_output_0, %/features/features.14/conv/conv.2/Constant_1_output_0)
#   %/features/features.14/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 576, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%/features/features.14/conv/conv.2/Clip_output_0, %onnx::Conv_655, %onnx::Conv_656)
#   %/features/features.14/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.14/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.14/conv/conv.5/Clip_output_0 = Clip(%/features/features.14/conv/conv.3/Conv_output_0, %/features/features.14/conv/conv.5/Constant_output_0, %/features/features.14/conv/conv.5/Constant_1_output_0)
#   %/features/features.14/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/conv/conv.5/Clip_output_0, %onnx::Conv_658, %onnx::Conv_659)
#   %/features/features.15/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.14/conv/conv.6/Conv_output_0, %onnx::Conv_661, %onnx::Conv_662)
#   %/features/features.15/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.15/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.15/conv/conv.2/Clip_output_0 = Clip(%/features/features.15/conv/conv.0/Conv_output_0, %/features/features.15/conv/conv.2/Constant_output_0, %/features/features.15/conv/conv.2/Constant_1_output_0)
#   %/features/features.15/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 960, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.15/conv/conv.2/Clip_output_0, %onnx::Conv_664, %onnx::Conv_665)
#   %/features/features.15/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.15/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.15/conv/conv.5/Clip_output_0 = Clip(%/features/features.15/conv/conv.3/Conv_output_0, %/features/features.15/conv/conv.5/Constant_output_0, %/features/features.15/conv/conv.5/Constant_1_output_0)
#   %/features/features.15/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/conv/conv.5/Clip_output_0, %onnx::Conv_667, %onnx::Conv_668)
#   %/features/features.15/Add_output_0 = Add(%/features/features.14/conv/conv.6/Conv_output_0, %/features/features.15/conv/conv.6/Conv_output_0)
#   %/features/features.16/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.15/Add_output_0, %onnx::Conv_670, %onnx::Conv_671)
#   %/features/features.16/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.16/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.16/conv/conv.2/Clip_output_0 = Clip(%/features/features.16/conv/conv.0/Conv_output_0, %/features/features.16/conv/conv.2/Constant_output_0, %/features/features.16/conv/conv.2/Constant_1_output_0)
#   %/features/features.16/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 960, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.16/conv/conv.2/Clip_output_0, %onnx::Conv_673, %onnx::Conv_674)
#   %/features/features.16/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.16/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.16/conv/conv.5/Clip_output_0 = Clip(%/features/features.16/conv/conv.3/Conv_output_0, %/features/features.16/conv/conv.5/Constant_output_0, %/features/features.16/conv/conv.5/Constant_1_output_0)
#   %/features/features.16/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.16/conv/conv.5/Clip_output_0, %onnx::Conv_676, %onnx::Conv_677)
#   %/features/features.16/Add_output_0 = Add(%/features/features.15/Add_output_0, %/features/features.16/conv/conv.6/Conv_output_0)
#   %/features/features.17/conv/conv.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.16/Add_output_0, %onnx::Conv_679, %onnx::Conv_680)
#   %/features/features.17/conv/conv.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.17/conv/conv.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.17/conv/conv.2/Clip_output_0 = Clip(%/features/features.17/conv/conv.0/Conv_output_0, %/features/features.17/conv/conv.2/Constant_output_0, %/features/features.17/conv/conv.2/Constant_1_output_0)
#   %/features/features.17/conv/conv.3/Conv_output_0 = Conv[dilations = [1, 1], group = 960, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%/features/features.17/conv/conv.2/Clip_output_0, %onnx::Conv_682, %onnx::Conv_683)
#   %/features/features.17/conv/conv.5/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.17/conv/conv.5/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.17/conv/conv.5/Clip_output_0 = Clip(%/features/features.17/conv/conv.3/Conv_output_0, %/features/features.17/conv/conv.5/Constant_output_0, %/features/features.17/conv/conv.5/Constant_1_output_0)
#   %/features/features.17/conv/conv.6/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.17/conv/conv.5/Clip_output_0, %onnx::Conv_685, %onnx::Conv_686)
#   %/features/features.18/features.18.0/Conv_output_0 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%/features/features.17/conv/conv.6/Conv_output_0, %onnx::Conv_688, %onnx::Conv_689)
#   %/features/features.18/features.18.2/Constant_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.18/features.18.2/Constant_1_output_0 = Constant[value = <Scalar Tensor []>]()
#   %/features/features.18/features.18.2/Clip_output_0 = Clip(%/features/features.18/features.18.0/Conv_output_0, %/features/features.18/features.18.2/Constant_output_0, %/features/features.18/features.18.2/Constant_1_output_0)
#   %/ReduceMean_output_0 = ReduceMean[axes = [3], keepdims = 0](%/features/features.18/features.18.2/Clip_output_0)
#   %533 = ReduceMean[axes = [2], keepdims = 0](%/ReduceMean_output_0)
#   return %533
# }
# 2024-04-03 17:14:46.302631537 [E:onnxruntime:Default, env.cc:251 ThreadMain] pthread_setaffinity_np failed for thread: 3537669, index: 2, mask: {3, }, error code: 22 error msg: Invalid argument. Specify the number of threads explicitly so the affinity is not set.
# [array([[0.23643705, 1.2312772 , 1.8156841 , ..., 0.10831792, 0.16736968,
#         0.70337003]], dtype=float32)]

# %%
# use atc convert onnx to om
# !atc --model=../../model/mobilenetv2.onnx --framework=5 --output=../../model/mobilenetv2 --input_format=NCHW  --soc_version=Ascend310B4
# Out:
# ATC start working now, please wait for a moment.
# ^C

# %%
from ais_bench.infer.interface import InferSession
om_path = "../../model/mobilenetv2.om"  # om模型文件的路径

# %%
import acl

device_id = 0
NPY_FLOAT32 = 11
ACL_MEMCPY_HOST_TO_HOST = 0
ACL_MEMCPY_HOST_TO_DEVICE = 1
ACL_MEMCPY_DEVICE_TO_HOST = 2
ACL_MEMCPY_DEVICE_TO_DEVICE = 3
ACL_MEM_MALLOC_HUGE_FIRST = 0
ACL_DEVICE, ACL_HOST = 0, 1
ACL_SUCCESS = 0

# ======运行管理资源申请======

# init acl resource
ret = acl.init()
if ret != ACL_SUCCESS:
    print('acl init failed, errorCode is', ret)

# 1.指定运算的Device。
ret = acl.rt.set_device(device_id)
print("set device ret:", ret, "device_id:", device_id)

# 2.显式创建一个Context，用于管理Stream对象。
context, ret = acl.rt.create_context(device_id)
print("create context ret:", ret)

# 3.显式创建一个Stream。
#用于维护一些异步操作的执行顺序，确保按照应用程序中的代码调用顺序执行任务。
stream, ret = acl.rt.create_stream()
print("create stream ret:", ret)

# load model from file
model_id, ret = acl.mdl.load_from_file(om_path)
if ret != ACL_SUCCESS:
    print('load model failed, errorCode is', ret)

# create description of model
model_desc = acl.mdl.create_desc()
ret = acl.mdl.get_desc(model_desc, model_id)
if ret != ACL_SUCCESS:
    print('get desc failed, errorCode is', ret)

# 2.准备模型推理的输入数据集。
# 创建aclmdlDataset类型的数据，描述模型推理的输入。
load_input_dataset = acl.mdl.create_dataset()
# 获取模型输入的数量。
input_size = acl.mdl.get_num_inputs(model_desc)
input_data = []
# 循环为每个输入申请内存，并将每个输入添加到aclmdlDataset类型的数据中。
for i in range(input_size):
    buffer_size = acl.mdl.get_input_size_by_index(model_desc, i)
    print("input buffer[", i, "] size:", buffer_size)
    # 申请输入内存。
    buffer, ret = acl.rt.malloc(buffer_size, ACL_MEM_MALLOC_HUGE_FIRST)
    data = acl.create_data_buffer(buffer, buffer_size)
    _, ret = acl.mdl.add_dataset_buffer(load_input_dataset, data)
    print("add input dataset ret:", ret)
    input_data.append({"buffer": buffer, "size": buffer_size})

# 3.准备模型推理的输出数据集。
# 创建aclmdlDataset类型的数据，描述模型推理的输出。
load_output_dataset = acl.mdl.create_dataset()
# 获取模型输出的数量。
output_size = acl.mdl.get_num_outputs(model_desc)
output_data = []
# 循环为每个输出申请内存，并将每个输出添加到aclmdlDataset类型的数据中。
for i in range(output_size):
    buffer_size = acl.mdl.get_output_size_by_index(model_desc, i)
    print("output buffer[", i, "] size:", buffer_size)
    # 申请输出内存。
    buffer, ret = acl.rt.malloc(buffer_size, ACL_MEM_MALLOC_HUGE_FIRST)
    data = acl.create_data_buffer(buffer, buffer_size)
    _, ret = acl.mdl.add_dataset_buffer(load_output_dataset, data)
    print("add output dataset ret:", ret)
    output_data.append({"buffer": buffer, "size": buffer_size})
# Out:
# set device ret: 0 device_id: 0
# create context ret: 0
# create stream ret: 0
# input buffer[ 0 ] size: 602112
# add input dataset ret: 0
# output buffer[ 0 ] size: 5120
# add output dataset ret: 0
